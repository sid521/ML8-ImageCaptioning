# %% [markdown]
# <a href="https://colab.research.google.com/github/sid521/ML8-ImageCaptioning/blob/main/Image_captioning_Video_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import tensorflow as tf
import cv2
from sklearn import preprocessing
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Dropout, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D, Concatenate, ReLU, LeakyReLU, Reshape, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import metrics
from tensorflow.keras.preprocessing.text import tokenizer_from_json
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras import utils
from tqdm import tqdm
import matplotlib.pyplot as plt
import collections
import random
import time
#from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cdist
import matplotlib.image as mpimg
import json
from PIL import Image
#from transformers import T5ForConditionalGeneration, T5Tokenizer

# %%
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

TF_FORCE_GPU_ALLOW_GROWTH=1

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Download the coco dataset of images and their captions files
# MSCOCO captions dataset consists of 83,000 images with each image having 5 captions .Approximately 13GB

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip) #remove zip file

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)# remove zip file
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 6s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 327s 0us/step

# %% [markdown]
# ## limiting  the size of the training set for faster training
# In this case limiting the number of images to 15000 with each image containing 5 captions resulting in 30000 captions

# %% [markdown]
# ## Preprocessing the captions

# %%
#open the annotations(captions) .json file
annotation_file = os.path.abspath('.')+'/annotations/captions_train2014.json'
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>" 
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
# shuffling the images
import random
image_paths = list(image_path_to_caption.keys())
random.Random(0).shuffle(image_paths)

# Select the first 15000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 75,000 examples.

# %%
train_image_paths = image_paths[:15000]
print(len(train_image_paths))
# Out:
# 50000

# %%
# form lists with captions and their respective image
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    train_captions.extend(caption_list)
    img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A dog chasing a baby cow across a lush green field. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x400 at 0x7F2694E4F110>

# %% [markdown]
# ### Initialising resnet50 model for feature extraction

# %%
#preprocess the image before feeding in to the model
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224)) # (224,224) is the default input of resnet50
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ### Identity block

# %% [markdown]
# ![identity block.png](data:image/png;base64,...)

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of identity block as of above figure
    skips over two convolution block.
    Args:
    X -- input tensor
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block a tensor 
    """
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    F1, F2, F3 = filters
    
    X_shortcut = X
        
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
        
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Add shortcut value to main path
    X = Add()([X_shortcut, X])
    X = Activation('relu')(X)
        
    return X

# %% [markdown]
# ### Convolutional Block

# %% [markdown]
# ![convolutional block.png](data:image/png;base64,...)

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block as defined in above figure
    
    Arguments:
    X -- input tensor 
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block a tensor 
    """
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
    X_shortcut = X
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)
    X = Add()([X_shortcut, X])
    X = Activation('relu')(X)
   
    return X

# %%
def top_5_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=5)

# %% [markdown]
# ## ResNet

# %% [markdown]
# ![resnet.png](data:image/png;base64,...)

# %%
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
def ResNet50(input_shape = (224, 224, 3)):

    X_input = Input(input_shape)
    X = ZeroPadding2D((3, 3))(X_input)
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')
    model = Model(inputs = X_input, outputs = X, name='ResNet50')
    weights_path = utils.get_file('resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
                                    WEIGHTS_PATH_NO_TOP,
                                    cache_subdir='models',
                                    md5_hash='a268eb855778b3df3c7506639542a6af')
    model.load_weights(weights_path,by_name=True)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc',top_5_accuracy])
    return model

# %%
image_features_extract_model = ResNet50(input_shape = (224, 224, 3)) #output_shape=(7,7,2048)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step

# %% [markdown]
# Saving resnet50 model for direct predictions in future cases

# %%
saving the model in .hdf5 file
choose your path
model_path ='weights/resnet50.hdf5'
image_features_extract_model.save_weights(model_path)

# %% [markdown]
# preprocessing the training images and saving the output features to the disk . keeping them all in the memory will consume a lot of RAM which is not recommended. Saving them to disk as .npy files and lazy loading them using tf.data.Dataset when required is a better way to save memory

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

#batch size=16
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    # print(path_of_feature)
    np.save(path_of_feature, bf.numpy())
    os.remove(path_of_feature)
# Out:
# 100%|██████████| 3125/3125 [09:22<00:00,  5.56it/s]

# %% [markdown]
# ## Preprocess and tokenize the captions
#
# * Tokenize the captions (for example, by splitting on spaces). This gives us a  vocabulary of all of the unique words in the data
# * limiting the vocabulary size to the top 5,000 words (to save memory). Replace all other words with the token "UNK" (unknown).
# * Create word-to-index and index-to-word mappings.
# * Finally, pad all sequences to be the same length as the longest one.

# %%
# Find the maximum length of any caption in the dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~')
tokenizer.fit_on_texts(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %% [markdown]
# Saving the tokenizer to directly load it for prediction

# %%
import io
tokenizer_json = tokenizer.to_json()
with io.open('weights/tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)
print(max_length)
# Out:
# 52

# %% [markdown]
# ## Split the data into training and testing

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training, validation, test sets using an 95-4-1 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.95)
slice_index_1 = int(len(img_keys)*0.99)
img_name_train_keys, img_name_val_keys,img_name_test_keys = img_keys[:slice_index], img_keys[slice_index:slice_index_1],img_keys[slice_index_1:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

img_name_test = []
cap_test = []
for imgtest in img_name_test_keys:
  captest_len = len(img_to_cap_vector[imgtest])
  img_name_test.extend([imgtest] * captest_len)
  cap_test.extend(img_to_cap_vector[imgtest])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val),len(cap_test),len(img_name_test)
# Out:
# (237613, 237613, 10006, 10006, 2500, 2500)

# %% [markdown]
# ## Create a tf.data dataset for training

# %% [markdown]
# images and captions are ready.creating a `tf.data` dataset to use for training the model.

# %%
# Choose optimal parameters depending upon system configuration
# Can be changed depending upon your system configuration
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from resnet50 is (49, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 49

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Model
#
# *  extract the features from the lower convolutional layer of Resnet50 giving us a vector of shape (7, 7, 2048).
# * squashing that to a shape of (49, 2048).
# * This vector is then passed through the CNN Encoder
# * The RNN attends over the image to predict the next word.

# %% [markdown]
# ### Attention model

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 49, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 49, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 49, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 49, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# ###  CNN Encoder Model

# %%
class CNN_Encoder(tf.keras.Model):
    # This encoder passes those features extracted from resnet50 (49,2048)through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 49, embedding_dim)
        self.fc1 = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc1(x)
        x = tf.nn.relu(x)
        return x

# %% [markdown]
# ### RNN Decoder Model

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru1 = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.gru2 = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(self.units)
    self.fc3 = tf.keras.layers.Dense(vocab_size)
    self.drop = tf.keras.layers.Dropout(0.25)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
    x= self.drop(x)

    # passing the concatenated vector to the stack of GRU layers
    output, state = self.gru1(x)
    x = self.drop(output)
    output, state_ = self.gru2(x)
    x = self.drop(output)
    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(x)
    x= self.drop(x)
    x = self.fc2(x)
    x= self.drop(x)
    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))
    # output shape == (batch_size * max_length, vocab)
    x = self.fc3(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
# creating instances of the model
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
#loss function
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoint_gru2_encode_1/train_2"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Training
#
# * extract the features stored in the respective `.npy` files and then pass those features through the encoder.
# * The encoder output, hidden state(initialized to 0) and the decoder input (which is the start token) is passed to the decoder.
# * The decoder returns the predictions and the decoder hidden state.
# * The decoder hidden state is then passed back into the model and the predictions are used to calculate the loss.
# * Use teacher forcing to decide the next input to the decoder.
# * Teacher forcing is the technique where the target word is passed as the next input to the decoder.
# * The final step is to calculate the gradients and apply it to the optimizer and backpropagate.

# %%
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0
    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] *
                               target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables
    #   print(trainable_variables)

    gradients = tape.gradient(loss, trainable_variables)
    #   print('here')

    optimizer.apply_gradients(zip(gradients, trainable_variables))
    #   print('this')
    return loss, total_loss

# %% [markdown]
# ### Training

# %%
EPOCHS = 20
for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0
    i=0
    for (batch, (img_tensor, target)) in enumerate(dataset):
#         i=i+1
#         print(i)
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 1.8847
# Epoch 1 Batch 100 Loss 1.0429
# Epoch 1 Batch 200 Loss 0.9056
# Epoch 1 Batch 300 Loss 0.9018
# Epoch 1 Batch 400 Loss 0.8149
# Epoch 1 Batch 500 Loss 0.7646
# Epoch 1 Batch 600 Loss 0.7607
# Epoch 1 Batch 700 Loss 0.7782
# Epoch 1 Batch 800 Loss 0.6735
# Epoch 1 Batch 900 Loss 0.7228
# Epoch 1 Batch 1000 Loss 0.7695
# Epoch 1 Batch 1100 Loss 0.6599
# Epoch 1 Batch 1200 Loss 0.6582
# Epoch 1 Batch 1300 Loss 0.7471
# Epoch 1 Batch 1400 Loss 0.7504
# Epoch 1 Batch 1500 Loss 0.6327
# Epoch 1 Batch 1600 Loss 0.7279
# Epoch 1 Batch 1700 Loss 0.6848
# Epoch 1 Batch 1800 Loss 0.6393
# Epoch 1 Batch 1900 Loss 0.6857
# Epoch 1 Batch 2000 Loss 0.6873
# Epoch 1 Batch 2100 Loss 0.7087
# Epoch 1 Batch 2200 Loss 0.6801
# Epoch 1 Batch 2300 Loss 0.6850
# Epoch 1 Batch 2400 Loss 0.6629
# Epoch 1 Batch 2500 Loss 0.6800
# Epoch 1 Batch 2600 Loss 0.6074
# Epoch 1 Batch 2700 Loss 0.6112
# Epoch 1 Batch 2800 Loss 0.6723
# Epoch 1 Batch 2900 Loss 0.7575
# Epoch 1 Batch 3000 Loss 0.6447
# Epoch 1 Batch 3100 Loss 0.7066
# Epoch 1 Batch 3200 Loss 0.6693
# Epoch 1 Batch 3300 Loss 0.6555
# Epoch 1 Batch 3400 Loss 0.6858
# Epoch 1 Batch 3500 Loss 0.6572
# Epoch 1 Batch 3600 Loss 0.6879
# Epoch 1 Batch 3700 Loss 0.5983
# Epoch 1 Loss 0.712911
# Time taken for 1 epoch 967.25 sec
#
# Epoch 2 Batch 0 Loss 0.6885
# Epoch 2 Batch 100 Loss 0.5884
# Epoch 2 Batch 200 Loss 0.6330
# Epoch 2 Batch 300 Loss 0.5906
# Epoch 2 Batch 400 Loss 0.6468
# Epoch 2 Batch 500 Loss 0.6572
# Epoch 2 Batch 600 Loss 0.5894
# Epoch 2 Batch 700 Loss 0.5957
# Epoch 2 Batch 800 Loss 0.6119
# Epoch 2 Batch 900 Loss 0.5807
# Epoch 2 Batch 1000 Loss 0.6088
# Epoch 2 Batch 1100 Loss 0.5947
# Epoch 2 Batch 1200 Loss 0.6798
# Epoch 2 Batch 1300 Loss 0.6387
# Epoch 2 Batch 1400 Loss 0.6051
# Epoch 2 Batch 1500 Loss 0.5573
# Epoch 2 Batch 1600 Loss 0.5952
# Epoch 2 Batch 1700 Loss 0.7006
# Epoch 2 Batch 1800 Loss 0.6807
# Epoch 2 Batch 1900 Loss 0.5906
# Epoch 2 Batch 2000 Loss 0.6847
# Epoch 2 Batch 2100 Loss 0.6292
# Epoch 2 Batch 2200 Loss 0.5892
# Epoch 2 Batch 2300 Loss 0.6071
# Epoch 2 Batch 2400 Loss 0.6126
# Epoch 2 Batch 2500 Loss 0.5935
# Epoch 2 Batch 2600 Loss 0.6014
# Epoch 2 Batch 2700 Loss 0.5908
# Epoch 2 Batch 2800 Loss 0.6029
# Epoch 2 Batch 2900 Loss 0.6199
# Epoch 2 Batch 3000 Loss 0.6389
# Epoch 2 Batch 3100 Loss 0.5799
# Epoch 2 Batch 3200 Loss 0.6246
# Epoch 2 Batch 3300 Loss 0.6075
# Epoch 2 Batch 3400 Loss 0.6536
# Epoch 2 Batch 3500 Loss 0.7034
# Epoch 2 Batch 3600 Loss 0.6411
# Epoch 2 Batch 3700 Loss 0.5695
# Epoch 2 Loss 0.615518
# Time taken for 1 epoch 810.45 sec
#
# Epoch 3 Batch 0 Loss 0.5913
# Epoch 3 Batch 100 Loss 0.5903
# Epoch 3 Batch 200 Loss 0.5973
# Epoch 3 Batch 300 Loss 0.5679
# Epoch 3 Batch 400 Loss 0.5680
# Epoch 3 Batch 500 Loss 0.6221
# Epoch 3 Batch 600 Loss 0.6731
# Epoch 3 Batch 700 Loss 0.6144
# Epoch 3 Batch 800 Loss 0.5816
# Epoch 3 Batch 900 Loss 0.6222
# Epoch 3 Batch 1000 Loss 0.6170
# Epoch 3 Batch 1100 Loss 0.6203
# Epoch 3 Batch 1200 Loss 0.6639
# Epoch 3 Batch 1300 Loss 0.6374
# Epoch 3 Batch 1400 Loss 0.6192
# Epoch 3 Batch 1500 Loss 0.5724
# Epoch 3 Batch 1600 Loss 0.6114
# Epoch 3 Batch 1700 Loss 0.5583
# Epoch 3 Batch 1800 Loss 0.5689
# Epoch 3 Batch 1900 Loss 0.5730
# Epoch 3 Batch 2000 Loss 0.6344
# Epoch 3 Batch 2100 Loss 0.6106
# Epoch 3 Batch 2200 Loss 0.4845
# Epoch 3 Batch 2300 Loss 0.5341
# Epoch 3 Batch 2400 Loss 0.6497
# Epoch 3 Batch 2500 Loss 0.6162
# Epoch 3 Batch 2600 Loss 0.5535
# Epoch 3 Batch 2700 Loss 0.5895
# Epoch 3 Batch 2800 Loss 0.5645
# Epoch 3 Batch 2900 Loss 0.5731
# Epoch 3 Batch 3000 Loss 0.6608
# Epoch 3 Batch 3100 Loss 0.7032
# Epoch 3 Batch 3200 Loss 0.5199
# Epoch 3 Batch 3300 Loss 0.5532
# Epoch 3 Batch 3400 Loss 0.5729
# Epoch 3 Batch 3500 Loss 0.6185
# Epoch 3 Batch 3600 Loss 0.6023
# Epoch 3 Batch 3700 Loss 0.6431
# Epoch 3 Loss 0.584388
# Time taken for 1 epoch 862.36 sec
#
# Epoch 4 Batch 0 Loss 0.5612
# Epoch 4 Batch 100 Loss 0.5620
# Epoch 4 Batch 200 Loss 0.5832
# Epoch 4 Batch 300 Loss 0.5648
# Epoch 4 Batch 400 Loss 0.5828
# Epoch 4 Batch 500 Loss 0.5345
# Epoch 4 Batch 600 Loss 0.5402
# Epoch 4 Batch 700 Loss 0.6257
# Epoch 4 Batch 800 Loss 0.5825
# Epoch 4 Batch 900 Loss 0.5408
# Epoch 4 Batch 1000 Loss 0.5554
# Epoch 4 Batch 1100 Loss 0.5612
# Epoch 4 Batch 1200 Loss 0.5843
# Epoch 4 Batch 1300 Loss 0.5591
# Epoch 4 Batch 1400 Loss 0.5509
# Epoch 4 Batch 1500 Loss 0.5867
# Epoch 4 Batch 1600 Loss 0.6238
# Epoch 4 Batch 1700 Loss 0.5781
# Epoch 4 Batch 1800 Loss 0.5765
# Epoch 4 Batch 1900 Loss 0.5449
# Epoch 4 Batch 2000 Loss 0.5689
# Epoch 4 Batch 2100 Loss 0.5952
# Epoch 4 Batch 2200 Loss 0.5579
# Epoch 4 Batch 2300 Loss 0.5266
# Epoch 4 Batch 2400 Loss 0.6514
# Epoch 4 Batch 2500 Loss 0.5640
# Epoch 4 Batch 2600 Loss 0.5789
# Epoch 4 Batch 2700 Loss 0.5651
# Epoch 4 Batch 2800 Loss 0.5834
# Epoch 4 Batch 2900 Loss 0.5859
# Epoch 4 Batch 3000 Loss 0.5536
# Epoch 4 Batch 3100 Loss 0.5474
# Epoch 4 Batch 3200 Loss 0.5379
# Epoch 4 Batch 3300 Loss 0.6395
# Epoch 4 Batch 3400 Loss 0.5217
# Epoch 4 Batch 3500 Loss 0.5929
# Epoch 4 Batch 3600 Loss 0.5746
# Epoch 4 Batch 3700 Loss 0.4945
# Epoch 4 Loss 0.563704
# Time taken for 1 epoch 811.60 sec
#
# Epoch 5 Batch 0 Loss 0.5639
# Epoch 5 Batch 100 Loss 0.5699
# Epoch 5 Batch 200 Loss 0.5205
# Epoch 5 Batch 300 Loss 0.5193
# Epoch 5 Batch 400 Loss 0.4948
# Epoch 5 Batch 500 Loss 0.5603
# Epoch 5 Batch 600 Loss 0.5362
# Epoch 5 Batch 700 Loss 0.5269
# Epoch 5 Batch 800 Loss 0.5881
# Epoch 5 Batch 900 Loss 0.5419
# Epoch 5 Batch 1000 Loss 0.5538
# Epoch 5 Batch 1100 Loss 0.5651
# Epoch 5 Batch 1200 Loss 0.5312
# Epoch 5 Batch 1300 Loss 0.5507
# Epoch 5 Batch 1400 Loss 0.5517
# Epoch 5 Batch 1500 Loss 0.5161
# Epoch 5 Batch 1600 Loss 0.5455
# Epoch 5 Batch 1700 Loss 0.5511
# Epoch 5 Batch 1800 Loss 0.6030
# Epoch 5 Batch 1900 Loss 0.5770
# Epoch 5 Batch 2000 Loss 0.5783
# Epoch 5 Batch 2100 Loss 0.5560
# Epoch 5 Batch 2200 Loss 0.5622
# Epoch 5 Batch 2300 Loss 0.6294
# Epoch 5 Batch 2400 Loss 0.5427
# Epoch 5 Batch 2500 Loss 0.5872
# Epoch 5 Batch 2600 Loss 0.4948
# Epoch 5 Batch 2700 Loss 0.5474
# Epoch 5 Batch 2800 Loss 0.4785
# Epoch 5 Batch 2900 Loss 0.5234
# Epoch 5 Batch 3000 Loss 0.6030
# Epoch 5 Batch 3100 Loss 0.5614
# Epoch 5 Batch 3200 Loss 0.5153
# Epoch 5 Batch 3300 Loss 0.5412
# Epoch 5 Batch 3400 Loss 0.4809
# Epoch 5 Batch 3500 Loss 0.5202
# Epoch 5 Batch 3600 Loss 0.6088
# Epoch 5 Batch 3700 Loss 0.5116
# Epoch 5 Loss 0.547019
# Time taken for 1 epoch 813.86 sec
#
# Epoch 6 Batch 0 Loss 0.5468
# Epoch 6 Batch 100 Loss 0.5807
# Epoch 6 Batch 200 Loss 0.5424
# Epoch 6 Batch 300 Loss 0.5759
# Epoch 6 Batch 400 Loss 0.4934
# Epoch 6 Batch 500 Loss 0.5463
# Epoch 6 Batch 600 Loss 0.4967
# Epoch 6 Batch 700 Loss 0.5187
# Epoch 6 Batch 800 Loss 0.5445
# Epoch 6 Batch 900 Loss 0.5532
# Epoch 6 Batch 1000 Loss 0.5307
# Epoch 6 Batch 1100 Loss 0.5046
# Epoch 6 Batch 1200 Loss 0.5048
# Epoch 6 Batch 1300 Loss 0.5214
# Epoch 6 Batch 1400 Loss 0.5237
# Epoch 6 Batch 1500 Loss 0.5566
# Epoch 6 Batch 1600 Loss 0.5187
# Epoch 6 Batch 1700 Loss 0.5342
# Epoch 6 Batch 1800 Loss 0.5254
# Epoch 6 Batch 1900 Loss 0.5518
# Epoch 6 Batch 2000 Loss 0.4890
# Epoch 6 Batch 2100 Loss 0.4639
# Epoch 6 Batch 2200 Loss 0.5310
# Epoch 6 Batch 2300 Loss 0.5658
# Epoch 6 Batch 2400 Loss 0.4811
# Epoch 6 Batch 2500 Loss 0.5238
# Epoch 6 Batch 2600 Loss 0.4938
# Epoch 6 Batch 2700 Loss 0.5212
# Epoch 6 Batch 2800 Loss 0.5067
# Epoch 6 Batch 2900 Loss 0.5481
# Epoch 6 Batch 3000 Loss 0.5284
# Epoch 6 Batch 3100 Loss 0.5150
# Epoch 6 Batch 3200 Loss 0.5591
# Epoch 6 Batch 3300 Loss 0.4929
# Epoch 6 Batch 3400 Loss 0.4910
# Epoch 6 Batch 3500 Loss 0.5031
# Epoch 6 Batch 3600 Loss 0.5202
# Epoch 6 Batch 3700 Loss 0.4790
# Epoch 6 Loss 0.532753
# Time taken for 1 epoch 812.99 sec
#
# Epoch 7 Batch 0 Loss 0.5998
# Epoch 7 Batch 100 Loss 0.5083
# Epoch 7 Batch 200 Loss 0.5505
# Epoch 7 Batch 300 Loss 0.5426
# Epoch 7 Batch 400 Loss 0.5456
# Epoch 7 Batch 500 Loss 0.5121
# Epoch 7 Batch 600 Loss 0.5387
# Epoch 7 Batch 700 Loss 0.5298
# Epoch 7 Batch 800 Loss 0.5430
# Epoch 7 Batch 900 Loss 0.4432
# Epoch 7 Batch 1000 Loss 0.5105
# Epoch 7 Batch 1100 Loss 0.5280
# Epoch 7 Batch 1200 Loss 0.4692
# Epoch 7 Batch 1300 Loss 0.5310
# Epoch 7 Batch 1400 Loss 0.5307
# Epoch 7 Batch 1500 Loss 0.5234
# Epoch 7 Batch 1600 Loss 0.5896
# Epoch 7 Batch 1700 Loss 0.5040
# Epoch 7 Batch 1800 Loss 0.4430
# Epoch 7 Batch 1900 Loss 0.5588
# Epoch 7 Batch 2000 Loss 0.5346
# Epoch 7 Batch 2100 Loss 0.5139
# Epoch 7 Batch 2200 Loss 0.4877
# Epoch 7 Batch 2300 Loss 0.4857
# Epoch 7 Batch 2400 Loss 0.5368
# Epoch 7 Batch 2500 Loss 0.5302
# Epoch 7 Batch 2600 Loss 0.5410
# Epoch 7 Batch 2700 Loss 0.5301
# Epoch 7 Batch 2800 Loss 0.4743
# Epoch 7 Batch 2900 Loss 0.5434
# Epoch 7 Batch 3000 Loss 0.5532
# Epoch 7 Batch 3100 Loss 0.4859
# Epoch 7 Batch 3200 Loss 0.5398
# Epoch 7 Batch 3300 Loss 0.4783
# Epoch 7 Batch 3400 Loss 0.4503
# Epoch 7 Batch 3500 Loss 0.5499
# Epoch 7 Batch 3600 Loss 0.5201
# Epoch 7 Batch 3700 Loss 0.4891
# Epoch 7 Loss 0.520528
# Time taken for 1 epoch 862.29 sec
#
# Epoch 8 Batch 0 Loss 0.5614
# Epoch 8 Batch 100 Loss 0.4707
# Epoch 8 Batch 200 Loss 0.5168
# Epoch 8 Batch 300 Loss 0.5167
# Epoch 8 Batch 400 Loss 0.4996
# Epoch 8 Batch 500 Loss 0.5287
# Epoch 8 Batch 600 Loss 0.4983
# Epoch 8 Batch 700 Loss 0.5281
# Epoch 8 Batch 800 Loss 0.4950
# Epoch 8 Batch 900 Loss 0.4567
# Epoch 8 Batch 1000 Loss 0.4648
# Epoch 8 Batch 1100 Loss 0.4943
# Epoch 8 Batch 1200 Loss 0.4828
# Epoch 8 Batch 1300 Loss 0.4828
# Epoch 8 Batch 1400 Loss 0.4968
# Epoch 8 Batch 1500 Loss 0.5236
# Epoch 8 Batch 1600 Loss 0.4883
# Epoch 8 Batch 1700 Loss 0.5152
# Epoch 8 Batch 1800 Loss 0.4781
# Epoch 8 Batch 1900 Loss 0.5041
# Epoch 8 Batch 2000 Loss 0.4993
# Epoch 8 Batch 2100 Loss 0.5021
# Epoch 8 Batch 2200 Loss 0.5202
# Epoch 8 Batch 2300 Loss 0.5095
# Epoch 8 Batch 2400 Loss 0.5379
# Epoch 8 Batch 2500 Loss 0.5374
# Epoch 8 Batch 2600 Loss 0.5312
# Epoch 8 Batch 2700 Loss 0.5011
# Epoch 8 Batch 2800 Loss 0.4788
# Epoch 8 Batch 2900 Loss 0.5435
# Epoch 8 Batch 3000 Loss 0.5261
# Epoch 8 Batch 3100 Loss 0.5131
# Epoch 8 Batch 3200 Loss 0.5060
# Epoch 8 Batch 3300 Loss 0.5046
# Epoch 8 Batch 3400 Loss 0.4920
# Epoch 8 Batch 3500 Loss 0.5791
# Epoch 8 Batch 3600 Loss 0.5522
# Epoch 8 Batch 3700 Loss 0.4792
# Epoch 8 Loss 0.509518
# Time taken for 1 epoch 811.82 sec
#
# Epoch 9 Batch 0 Loss 0.5301
# Epoch 9 Batch 100 Loss 0.4877
# Epoch 9 Batch 200 Loss 0.4877
# Epoch 9 Batch 300 Loss 0.5210
# Epoch 9 Batch 400 Loss 0.4618
# Epoch 9 Batch 500 Loss 0.5301
# Epoch 9 Batch 600 Loss 0.5303
# Epoch 9 Batch 700 Loss 0.5363
# Epoch 9 Batch 800 Loss 0.5345
# Epoch 9 Batch 900 Loss 0.5148
# Epoch 9 Batch 1000 Loss 0.4749
# Epoch 9 Batch 1100 Loss 0.4601
# Epoch 9 Batch 1200 Loss 0.4766
# Epoch 9 Batch 1300 Loss 0.4580
# Epoch 9 Batch 1400 Loss 0.4890
# Epoch 9 Batch 1500 Loss 0.4802
# Epoch 9 Batch 1600 Loss 0.5379
# Epoch 9 Batch 1700 Loss 0.4864
# Epoch 9 Batch 1800 Loss 0.4376
# Epoch 9 Batch 1900 Loss 0.4465
# Epoch 9 Batch 2000 Loss 0.5280
# Epoch 9 Batch 2100 Loss 0.5014
# Epoch 9 Batch 2200 Loss 0.4926
# Epoch 9 Batch 2300 Loss 0.5051
# Epoch 9 Batch 2400 Loss 0.5337
# Epoch 9 Batch 2500 Loss 0.5063
# Epoch 9 Batch 2600 Loss 0.4533
# Epoch 9 Batch 2700 Loss 0.5175
# Epoch 9 Batch 2800 Loss 0.4483
# Epoch 9 Batch 2900 Loss 0.5075
# Epoch 9 Batch 3000 Loss 0.4640
# Epoch 9 Batch 3100 Loss 0.5057
# Epoch 9 Batch 3200 Loss 0.5065
# Epoch 9 Batch 3300 Loss 0.4720
# Epoch 9 Batch 3400 Loss 0.5112
# Epoch 9 Batch 3500 Loss 0.4924
# Epoch 9 Batch 3600 Loss 0.4841
# Epoch 9 Batch 3700 Loss 0.5513
# Epoch 9 Loss 0.499865
# Time taken for 1 epoch 862.35 sec
#
# Epoch 10 Batch 0 Loss 0.4690
# Epoch 10 Batch 100 Loss 0.5405
# Epoch 10 Batch 200 Loss 0.4776
# Epoch 10 Batch 300 Loss 0.4941
# Epoch 10 Batch 400 Loss 0.4441
# Epoch 10 Batch 500 Loss 0.5505
# Epoch 10 Batch 600 Loss 0.5046
# Epoch 10 Batch 700 Loss 0.4822
# Epoch 10 Batch 800 Loss 0.4542
# Epoch 10 Batch 900 Loss 0.5005
# Epoch 10 Batch 1000 Loss 0.5014
# Epoch 10 Batch 1100 Loss 0.5110
# Epoch 10 Batch 1200 Loss 0.4548
# Epoch 10 Batch 1300 Loss 0.5352
# Epoch 10 Batch 1400 Loss 0.5260
# Epoch 10 Batch 1500 Loss 0.5155
# Epoch 10 Batch 1600 Loss 0.5363
# Epoch 10 Batch 1700 Loss 0.5547
# Epoch 10 Batch 1800 Loss 0.4611
# Epoch 10 Batch 1900 Loss 0.5047
# Epoch 10 Batch 2000 Loss 0.4810
# Epoch 10 Batch 2100 Loss 0.4991
# Epoch 10 Batch 2200 Loss 0.5160
# Epoch 10 Batch 2300 Loss 0.4842
# Epoch 10 Batch 2400 Loss 0.5083
# Epoch 10 Batch 2500 Loss 0.4995
# Epoch 10 Batch 2600 Loss 0.5089
# Epoch 10 Batch 2700 Loss 0.4708
# Epoch 10 Batch 2800 Loss 0.4683
# Epoch 10 Batch 2900 Loss 0.4838
# Epoch 10 Batch 3000 Loss 0.4908
# Epoch 10 Batch 3100 Loss 0.4474
# Epoch 10 Batch 3200 Loss 0.5017
# Epoch 10 Batch 3300 Loss 0.5121
# Epoch 10 Batch 3400 Loss 0.4641
# Epoch 10 Batch 3500 Loss 0.4879
# Epoch 10 Batch 3600 Loss 0.4404
# Epoch 10 Batch 3700 Loss 0.4515
# Epoch 10 Loss 0.490452
# Time taken for 1 epoch 809.70 sec
#
# Epoch 11 Batch 0 Loss 0.4846
# Epoch 11 Batch 100 Loss 0.4901
# Epoch 11 Batch 200 Loss 0.4933
# Epoch 11 Batch 300 Loss 0.5257
# Epoch 11 Batch 400 Loss 0.4789
# Epoch 11 Batch 500 Loss 0.4958
# Epoch 11 Batch 600 Loss 0.4615
# Epoch 11 Batch 700 Loss 0.5142
# Epoch 11 Batch 800 Loss 0.4559
# Epoch 11 Batch 900 Loss 0.4701
# Epoch 11 Batch 1000 Loss 0.5223
# Epoch 11 Batch 1100 Loss 0.5004
# Epoch 11 Batch 1200 Loss 0.4575
# Epoch 11 Batch 1300 Loss 0.4537
# Epoch 11 Batch 1400 Loss 0.4885
# Epoch 11 Batch 1500 Loss 0.4458
# Epoch 11 Batch 1600 Loss 0.5380
# Epoch 11 Batch 1700 Loss 0.4742
# Epoch 11 Batch 1800 Loss 0.4644
# Epoch 11 Batch 1900 Loss 0.4915
# Epoch 11 Batch 2000 Loss 0.4616
# Epoch 11 Batch 2100 Loss 0.4739
# Epoch 11 Batch 2200 Loss 0.4947
# Epoch 11 Batch 2300 Loss 0.5012
# Epoch 11 Batch 2400 Loss 0.4374
# Epoch 11 Batch 2500 Loss 0.4818
# Epoch 11 Batch 2600 Loss 0.4644
# Epoch 11 Batch 2700 Loss 0.4618
# Epoch 11 Batch 2800 Loss 0.4392
# Epoch 11 Batch 2900 Loss 0.5334
# Epoch 11 Batch 3000 Loss 0.5505
# Epoch 11 Batch 3100 Loss 0.4739
# Epoch 11 Batch 3200 Loss 0.5399
# Epoch 11 Batch 3300 Loss 0.4435
# Epoch 11 Batch 3400 Loss 0.4464
# Epoch 11 Batch 3500 Loss 0.4561
# Epoch 11 Batch 3600 Loss 0.4886
# Epoch 11 Batch 3700 Loss 0.4705
# Epoch 11 Loss 0.482351
# Time taken for 1 epoch 810.52 sec
#
# Epoch 12 Batch 0 Loss 0.4632
# Epoch 12 Batch 100 Loss 0.4755
# Epoch 12 Batch 200 Loss 0.5304
# Epoch 12 Batch 300 Loss 0.4556
# Epoch 12 Batch 400 Loss 0.4711
# Epoch 12 Batch 500 Loss 0.4443
# Epoch 12 Batch 600 Loss 0.4725
# Epoch 12 Batch 700 Loss 0.4943
# Epoch 12 Batch 800 Loss 0.4905
# Epoch 12 Batch 900 Loss 0.5191
# Epoch 12 Batch 1000 Loss 0.4625
# Epoch 12 Batch 1100 Loss 0.4851
# Epoch 12 Batch 1200 Loss 0.4040
# Epoch 12 Batch 1300 Loss 0.4501
# Epoch 12 Batch 1400 Loss 0.4434
# Epoch 12 Batch 1500 Loss 0.4077
# Epoch 12 Batch 1600 Loss 0.5112
# Epoch 12 Batch 1700 Loss 0.4356
# Epoch 12 Batch 1800 Loss 0.4372
# Epoch 12 Batch 1900 Loss 0.5395
# Epoch 12 Batch 2000 Loss 0.5149
# Epoch 12 Batch 2100 Loss 0.3938
# Epoch 12 Batch 2200 Loss 0.5127
# Epoch 12 Batch 2300 Loss 0.5148
# Epoch 12 Batch 2400 Loss 0.4690
# Epoch 12 Batch 2500 Loss 0.4629
# Epoch 12 Batch 2600 Loss 0.4791
# Epoch 12 Batch 2700 Loss 0.4555
# Epoch 12 Batch 2800 Loss 0.4878
# Epoch 12 Batch 2900 Loss 0.4482
# Epoch 12 Batch 3000 Loss 0.4626
# Epoch 12 Batch 3100 Loss 0.4376
# Epoch 12 Batch 3200 Loss 0.4545
# Epoch 12 Batch 3300 Loss 0.4500
# Epoch 12 Batch 3400 Loss 0.5010
# Epoch 12 Batch 3500 Loss 0.5097
# Epoch 12 Batch 3600 Loss 0.4618
# Epoch 12 Batch 3700 Loss 0.5113
# Epoch 12 Loss 0.474613
# Time taken for 1 epoch 813.18 sec
#
# Epoch 13 Batch 0 Loss 0.5138
# Epoch 13 Batch 100 Loss 0.4825
# Epoch 13 Batch 200 Loss 0.4712
# Epoch 13 Batch 300 Loss 0.5060
# Epoch 13 Batch 400 Loss 0.4157
# Epoch 13 Batch 500 Loss 0.4822
# Epoch 13 Batch 600 Loss 0.4656
# Epoch 13 Batch 700 Loss 0.4660
# Epoch 13 Batch 800 Loss 0.4921
# Epoch 13 Batch 900 Loss 0.4814
# Epoch 13 Batch 1000 Loss 0.4915
# Epoch 13 Batch 1100 Loss 0.4216
# Epoch 13 Batch 1200 Loss 0.5104
# Epoch 13 Batch 1300 Loss 0.4403
# Epoch 13 Batch 1400 Loss 0.4949
# Epoch 13 Batch 1500 Loss 0.4698
# Epoch 13 Batch 1600 Loss 0.4676
# Epoch 13 Batch 1700 Loss 0.4898
# Epoch 13 Batch 1800 Loss 0.4929
# Epoch 13 Batch 1900 Loss 0.4307
# Epoch 13 Batch 2000 Loss 0.4543
# Epoch 13 Batch 2100 Loss 0.5206
# Epoch 13 Batch 2200 Loss 0.4090
# Epoch 13 Batch 2300 Loss 0.4139
# Epoch 13 Batch 2400 Loss 0.4575
# Epoch 13 Batch 2500 Loss 0.5118
# Epoch 13 Batch 2600 Loss 0.4848
# Epoch 13 Batch 2700 Loss 0.4411
# Epoch 13 Batch 2800 Loss 0.4386
# Epoch 13 Batch 2900 Loss 0.4735
# Epoch 13 Batch 3000 Loss 0.4457
# Epoch 13 Batch 3100 Loss 0.4743
# Epoch 13 Batch 3200 Loss 0.4761
# Epoch 13 Batch 3300 Loss 0.4666
# Epoch 13 Batch 3400 Loss 0.4557
# Epoch 13 Batch 3500 Loss 0.4634
# Epoch 13 Batch 3600 Loss 0.5288
# Epoch 13 Batch 3700 Loss 0.4557
# Epoch 13 Loss 0.467259
# Time taken for 1 epoch 815.73 sec
#
# Epoch 14 Batch 0 Loss 0.4781
# Epoch 14 Batch 100 Loss 0.5372
# Epoch 14 Batch 200 Loss 0.4734
# Epoch 14 Batch 300 Loss 0.5014
# Epoch 14 Batch 400 Loss 0.4577
# Epoch 14 Batch 500 Loss 0.4538
# Epoch 14 Batch 600 Loss 0.4520
# Epoch 14 Batch 700 Loss 0.4461
# Epoch 14 Batch 800 Loss 0.4286
# Epoch 14 Batch 900 Loss 0.4819
# Epoch 14 Batch 1000 Loss 0.4497
# Epoch 14 Batch 1100 Loss 0.4574
# Epoch 14 Batch 1200 Loss 0.4511
# Epoch 14 Batch 1300 Loss 0.4302
# Epoch 14 Batch 1400 Loss 0.4416
# Epoch 14 Batch 1500 Loss 0.4680
# Epoch 14 Batch 1600 Loss 0.4998
# Epoch 14 Batch 1700 Loss 0.4893
# Epoch 14 Batch 1800 Loss 0.4265
# Epoch 14 Batch 1900 Loss 0.4335
# Epoch 14 Batch 2000 Loss 0.4614
# Epoch 14 Batch 2100 Loss 0.4850
# Epoch 14 Batch 2200 Loss 0.4253
# Epoch 14 Batch 2300 Loss 0.4781
# Epoch 14 Batch 2400 Loss 0.4390
# Epoch 14 Batch 2500 Loss 0.4794
# Epoch 14 Batch 2600 Loss 0.4389
# Epoch 14 Batch 2700 Loss 0.4471
# Epoch 14 Batch 2800 Loss 0.4418
# Epoch 14 Batch 2900 Loss 0.5064
# Epoch 14 Batch 3000 Loss 0.4357
# Epoch 14 Batch 3100 Loss 0.4308
# Epoch 14 Batch 3200 Loss 0.4247
# Epoch 14 Batch 3300 Loss 0.4375
# Epoch 14 Batch 3400 Loss 0.5035
# Epoch 14 Batch 3500 Loss 0.5328
# Epoch 14 Batch 3600 Loss 0.4505
# Epoch 14 Batch 3700 Loss 0.5110
# Epoch 14 Loss 0.460492
# Time taken for 1 epoch 814.39 sec
#
# Epoch 15 Batch 0 Loss 0.4432
# Epoch 15 Batch 100 Loss 0.4326
# Epoch 15 Batch 200 Loss 0.4866
# Epoch 15 Batch 300 Loss 0.4711
# Epoch 15 Batch 400 Loss 0.4164
# Epoch 15 Batch 500 Loss 0.4741
# Epoch 15 Batch 600 Loss 0.4283
# Epoch 15 Batch 700 Loss 0.4105
# Epoch 15 Batch 800 Loss 0.4483
# Epoch 15 Batch 900 Loss 0.4229
# Epoch 15 Batch 1000 Loss 0.4795
# Epoch 15 Batch 1100 Loss 0.5355
# Epoch 15 Batch 1200 Loss 0.4511
# Epoch 15 Batch 1300 Loss 0.4694
# Epoch 15 Batch 1400 Loss 0.4350
# Epoch 15 Batch 1500 Loss 0.5070
# Epoch 15 Batch 1600 Loss 0.4519
# Epoch 15 Batch 1700 Loss 0.4481
# Epoch 15 Batch 1800 Loss 0.4838
# Epoch 15 Batch 1900 Loss 0.4385
# Epoch 15 Batch 2000 Loss 0.4642
# Epoch 15 Batch 2100 Loss 0.4371
# Epoch 15 Batch 2200 Loss 0.4720
# Epoch 15 Batch 2300 Loss 0.4828
# Epoch 15 Batch 2400 Loss 0.5002
# Epoch 15 Batch 2500 Loss 0.4874
# Epoch 15 Batch 2600 Loss 0.4858
# Epoch 15 Batch 2700 Loss 0.4389
# Epoch 15 Batch 2800 Loss 0.4054
# Epoch 15 Batch 2900 Loss 0.4328
# Epoch 15 Batch 3000 Loss 0.4858
# Epoch 15 Batch 3100 Loss 0.5046
# Epoch 15 Batch 3200 Loss 0.4569
# Epoch 15 Batch 3300 Loss 0.4654
# Epoch 15 Batch 3400 Loss 0.4542
# Epoch 15 Batch 3500 Loss 0.4227
# Epoch 15 Batch 3600 Loss 0.4637
# Epoch 15 Batch 3700 Loss 0.4148
# Epoch 15 Loss 0.454886
# Time taken for 1 epoch 812.30 sec
#
# Epoch 16 Batch 0 Loss 0.4565
# Epoch 16 Batch 100 Loss 0.5038
# Epoch 16 Batch 200 Loss 0.4331
# Epoch 16 Batch 300 Loss 0.4540
# Epoch 16 Batch 400 Loss 0.4552
# Epoch 16 Batch 500 Loss 0.4999
# Epoch 16 Batch 600 Loss 0.4371
# Epoch 16 Batch 700 Loss 0.4188
# Epoch 16 Batch 800 Loss 0.4864
# Epoch 16 Batch 900 Loss 0.4681
# Epoch 16 Batch 1000 Loss 0.4299
# Epoch 16 Batch 1100 Loss 0.4601
# Epoch 16 Batch 1200 Loss 0.4316
# Epoch 16 Batch 1300 Loss 0.4202
# Epoch 16 Batch 1400 Loss 0.4710
# Epoch 16 Batch 1500 Loss 0.4369
# Epoch 16 Batch 1600 Loss 0.4627
# Epoch 16 Batch 1700 Loss 0.4536
# Epoch 16 Batch 1800 Loss 0.4406
# Epoch 16 Batch 1900 Loss 0.4539
# Epoch 16 Batch 2000 Loss 0.4786
# Epoch 16 Batch 2100 Loss 0.4328
# Epoch 16 Batch 2200 Loss 0.4483
# Epoch 16 Batch 2300 Loss 0.4521
# Epoch 16 Batch 2400 Loss 0.4305
# Epoch 16 Batch 2500 Loss 0.4566
# Epoch 16 Batch 2600 Loss 0.4279
# Epoch 16 Batch 2700 Loss 0.4623
# Epoch 16 Batch 2800 Loss 0.4444
# Epoch 16 Batch 2900 Loss 0.4538
# Epoch 16 Batch 3000 Loss 0.4609
# Epoch 16 Batch 3100 Loss 0.4252
# Epoch 16 Batch 3200 Loss 0.4370
# Epoch 16 Batch 3300 Loss 0.4679
# Epoch 16 Batch 3400 Loss 0.4228
# Epoch 16 Batch 3500 Loss 0.4502
# Epoch 16 Batch 3600 Loss 0.4678
# Epoch 16 Batch 3700 Loss 0.4452
# Epoch 16 Loss 0.449285
# Time taken for 1 epoch 814.52 sec
#
# Epoch 17 Batch 0 Loss 0.4343
# Epoch 17 Batch 100 Loss 0.4632
# Epoch 17 Batch 200 Loss 0.5002
# Epoch 17 Batch 300 Loss 0.4574
# Epoch 17 Batch 400 Loss 0.4505
# Epoch 17 Batch 500 Loss 0.4605
# Epoch 17 Batch 600 Loss 0.4506
# Epoch 17 Batch 700 Loss 0.4937
# Epoch 17 Batch 800 Loss 0.4745
# Epoch 17 Batch 900 Loss 0.4914
# Epoch 17 Batch 1000 Loss 0.4408
# Epoch 17 Batch 1100 Loss 0.4248
# Epoch 17 Batch 1200 Loss 0.4382
# Epoch 17 Batch 1300 Loss 0.4368
# Epoch 17 Batch 1400 Loss 0.4417
# Epoch 17 Batch 1500 Loss 0.4290
# Epoch 17 Batch 1600 Loss 0.4196
# Epoch 17 Batch 1700 Loss 0.4342
# Epoch 17 Batch 1800 Loss 0.4158
# Epoch 17 Batch 1900 Loss 0.4641
# Epoch 17 Batch 2000 Loss 0.4374
# Epoch 17 Batch 2100 Loss 0.4756
# Epoch 17 Batch 2200 Loss 0.4198
# Epoch 17 Batch 2300 Loss 0.5705
# Epoch 17 Batch 2400 Loss 0.4317
# Epoch 17 Batch 2500 Loss 0.4730
# Epoch 17 Batch 2600 Loss 0.4398
# Epoch 17 Batch 2700 Loss 0.4132
# Epoch 17 Batch 2800 Loss 0.4443
# Epoch 17 Batch 2900 Loss 0.4513
# Epoch 17 Batch 3000 Loss 0.4668
# Epoch 17 Batch 3100 Loss 0.4212
# Epoch 17 Batch 3200 Loss 0.4852
# Epoch 17 Batch 3300 Loss 0.4454
# Epoch 17 Batch 3400 Loss 0.3895
# Epoch 17 Batch 3500 Loss 0.4143
# Epoch 17 Batch 3600 Loss 0.5011
# Epoch 17 Batch 3700 Loss 0.4213
# Epoch 17 Loss 0.443444
# Time taken for 1 epoch 812.86 sec
#
# Epoch 18 Batch 0 Loss 0.4603
# Epoch 18 Batch 100 Loss 0.4312
# Epoch 18 Batch 200 Loss 0.4547
# Epoch 18 Batch 300 Loss 0.4736
# Epoch 18 Batch 400 Loss 0.4143
# Epoch 18 Batch 500 Loss 0.4342
# Epoch 18 Batch 600 Loss 0.4585
# Epoch 18 Batch 700 Loss 0.4319
# Epoch 18 Batch 800 Loss 0.4246
# Epoch 18 Batch 900 Loss 0.4824
# Epoch 18 Batch 1000 Loss 0.4423
# Epoch 18 Batch 1100 Loss 0.4093
# Epoch 18 Batch 1200 Loss 0.4752
# Epoch 18 Batch 1300 Loss 0.4455
# Epoch 18 Batch 1400 Loss 0.4409
# Epoch 18 Batch 1500 Loss 0.4323
# Epoch 18 Batch 1600 Loss 0.4540
# Epoch 18 Batch 1700 Loss 0.4193
# Epoch 18 Batch 1800 Loss 0.4629
# Epoch 18 Batch 1900 Loss 0.4442
# Epoch 18 Batch 2000 Loss 0.4975
# Epoch 18 Batch 2100 Loss 0.4265
# Epoch 18 Batch 2200 Loss 0.4557
# Epoch 18 Batch 2300 Loss 0.4721
# Epoch 18 Batch 2400 Loss 0.4631
# Epoch 18 Batch 2500 Loss 0.4450
# Epoch 18 Batch 2600 Loss 0.4028
# Epoch 18 Batch 2700 Loss 0.4490
# Epoch 18 Batch 2800 Loss 0.4473
# Epoch 18 Batch 2900 Loss 0.4592

# %%
# saving the encoder and decoder model weights
encoder_path='final_weights/encoder_gru_stack_2_512_enc_1.h5'
decoder_path='final_weights/decoder_gru_stack_2_512_enc_1.h5'
encoder.save_weights(encoder_path)
decoder.save_weights(decoder_path)

# %%
#loss plot
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Caption Prediction

# %% [markdown]
# ### Greedy search algorithm

# %%
# greedy search algoritm for caption generation/prediction and attention plot
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(
        img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(
            dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.argmax(predictions, 1)[0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %% [markdown]
# ### Beam search algorithm

# %%
# beam search algoritm for caption prediction
def beam_search_predictions(image, beam_index=2):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(
        img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []
    start = [tokenizer.word_index["<start>"]]
    start_word = [[start, 0.0]]
    while len(start_word[0][0]) < max_length:
        temp = []
        for s in start_word:
            dec_input = tf.expand_dims([s[0][-1]],1)
            preds, hidden, attention_weights = decoder(
                dec_input, features, hidden)
            word_preds = np.argsort(preds[0])[-beam_index:]
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
                prob += preds[0][w]
                temp.append([next_cap, prob])

        start_word = temp
        # Sorting according to the probabilities
        start_word = sorted(start_word, reverse=False, key=lambda l: l[1])
        # Getting the top words
        start_word = start_word[-beam_index:]

    start_word = start_word[-1][0]
    intermediate_caption = [tokenizer.index_word[i] for i in start_word]
    final_caption = []

    for i in intermediate_caption:
        if i != '<end>':
            final_caption.append(i)
        else:
            break

    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %% [markdown]
# ### Attention plot for visualisation

# %%
# function to plot attention using attention weights
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (7, 7))
        grid_size = max(np.ceil(len_result/2), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## captions on the validation set

# %%
# predicted caption on a random image from the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i]
                        for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a pair of giraffes graze in an enclosed area <end>
# Prediction Caption: a giraffe is standing next to a giraffe <end>
# C:\Users\shash\anaconda3\envs\imgcap\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Accuracy metric
#
# creating a psuedo metric for accuracy . the cosine simlarity of the predicted and actual captions is greater than than the threshold value (0.8) cosidered as correct (which is absolutly not) but for the sake of understanding the model performance

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
# similarity threshold 
threshold = 0.9
# psudeo accuracy calculation
correct=0
for ind in range(len(img_name_val)):
    img = img_name_val[ind]
    captions = img_to_cap_vector[img]
        for cap in captions:
        temp = ' '.join([tokenizer.index_word[i] for i in cap if i not in [0]])
        temp = temp.replace('<start>', ' ')
        temp = temp.replace('<end>', ' ')
        real_captions.append(temp)
    result, attention_plot = evaluate(image)
    res = ' '.join(result)
    result = res.replace('<end>', ' ')
    encodings = model.encode(real_captions)
    result_encoding = model.encode(result)
    sim_mat = 1 - (cdist(encodings, [result_encoding], 'cosine'))
    max_index = np.argmx(sim_mat)
    similarity = sim_mat[max_index]
    if similarity > threshold:
        correct = correct+1
accuracy = (correct/len(img_name_val))*100
print("Accuracy of validation images : {} %".format(accuracy))

# %% [markdown]
# # Captions on test images

# %%
# the cosine similarity of a random image in the test dataset
def similarity_score(index=None, verbose=True, view_image=False):
    """ index : the index of the test image in the img_name_test list.
                if none select a random image
        verbose: show text 
        view_image: display the the image"""
    real_captions = []
    if index == None or index >= len(img_name_test):
        rid = np.random.randint(0, len(img_name_test))
    else:
        rid = index
    image = img_name_test[rid]
    a = img_to_cap_vector[image]
    for cap in a:
        temp = ' '.join([tokenizer.index_word[i] for i in cap if i not in [0]])
        temp = temp.replace('<start>', ' ')
        temp = temp.replace('<end>', ' ')
        real_captions.append(temp)
    result, attention_plot = evaluate(image)
    res = ' '.join(result)
    result = res.replace('<end>', ' ')
    encodings = model.encode(real_captions)
    result_encoding = model.encode(result)
    sim_mat = 1 - (cdist(encodings, [result_encoding], 'cosine'))
    max_index = np.argmx(sim_mat)
    similarity = sim_mat[max_index]

    if verbose:
        print(
            'maximm cosine similarity from the 5 true captions and the predicted caption : ',
            similarity)
        print("true caption : ", real_captions[max_index])
        print('Prediction Caption:', result)
        if view_image:
            img = mpimg.imread(image)
            imgplot = plt.imshow(img)
    return similarity

# %%
similarity_score(20,view_image=True)
# Out:
# 0.8009817203895534
# mean cosine similarity between the 5 true captions and the predicted caption :  0.8009817203895534
# true captions :  ['  a room filled with a sculpture next to a table with people sitting at it  ', '  people seated around tables with flower <unk>  ', '  a fancy hotel lobby has flowers and shops  ', '  some white tables and chairs and a large vase with flowers  ', '  people are sitting at tables around a large vase with flowers  ']
# Prediction Caption: a man is sitting at a table and a flower tablecloth
# 0.8009817203895534

# %%
# cosine similarity of n random test images and their mean
def mean_similarity_n_images(n=10):
  similarities=[]
  randomlist = random.sample(range(0, len(img_name_test)), n)
  for i in randomlist:
    similarity = similarity_score(verbose=False)
    similarities.append(similarity)
  mean_similarity =sum( similarities)/len(similarities)
  print('mean cosine similarity of {} random images : '.format(n),mean_similarity)
  return similarities , mean_similarity

# %%
b = mean_similarity_n_images()
# Out:
# mean cosine similarity of 10 random images :  0.5179586030433062

# %%
# predict a image from your local directory
def greedy_predict(path):
    filename = os.path.abspath(path)
    img = Image.open(path)
    result, attention_plot = evaluate(path)
    res = ' '.join(result)
    result = res.replace('<end>',' ')
    print('Prediction Caption:', result)
    img_ = mpimg.imread(filename)
    plt.imshow(img_)

# %%
path = 'example.jpg'
greedy_predict(path)
# Out:
# Prediction Caption: a lone cow standing in the sand

# %% [markdown]
# # Video Summariser

# %% [markdown]
# ## Converting Video into frames

# %%
import cv2
list=[]
# Opens the Video file
cap= cv2.VideoCapture('/content/samplevideo.mp4')
i=0
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == False:
        total= i
        # 'total number of frames-1'  for the video
        print(total)
        break
    file_name_path = '/content/frames/frame' + str(i) + '.jpg' 
    list.append(file_name_path)   
    cv2.imwrite(file_name_path,frame)
    i+=1
 
cap.release()
cv2.destroyAllWindows()

# %%
i=0
predics=[]
# empty list to append the predicted captions for all the frames
while i<total:
  image = list[i]
  result, attention_plot = evaluate(image)
  res = ' '.join(result)
  result = res.replace('<end>',' ')
  predics.append(result)
  #list where captions associated to all frames of video are stored 
  i=i+60
  #taking 1 frame out of every 60 frames
  #considering 1 frame for every 2 seconds

# %%
# !pip install sentence-transformers

# %%
#Remove one of the consecutive image caption greater than certain cosine similarity threshold between the two captions
# threshold value is 0.50
import math
i=0
n=math.floor((total/60)+1)
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
while i<n-1:
  sentences=[]
  sentences.append(predics[i])
  if len(predics)>=i+1:
    break
  else:  
    sentences.append(predics[i+1])
  model=SentenceTransformer('bert-base-nli-mean-tokens')
  sentence_embeddings=model.encode(sentences)
  #sentence_embeddings.shape
  cs=cosine_similarity([sentence_embeddings[0]],sentence_embeddings[1])
  if cs>0.50:
    del predics[i]
  else:
    i=i+1

# %%
#number of sentences removed by threshold
print(n-len(predics))

# %% [markdown]
# #Summarizing the Text using T5 base Transformer

# %%
Text=" "
Text=Text+predics[0]
#concat all sentences in list and convert it into one paragraph
for i in range(1,int(n)):
  Text=Text+"."+predics[i]

# %%
#from transformers import T5ForConditionalGeneration, T5Tokenizer
# initialize the model architecture and weights
model = T5ForConditionalGeneration.from_pretrained("t5-base")
# initialize the model tokenizer
t5_tokenizer = T5Tokenizer.from_pretrained("t5-base")

# %%
#encode the text into tensor of integers using the appropriate tokenizer
inputs = t5_tokenizer.encode("summarize: " + Text, return_tensors="pt",truncation=True)

# %%
# summary output generation in form of tokens
outputs = model.generate(
    inputs, 
    max_length=512, 
    min_length=50, 
    length_penalty=2.0, 
    num_beams=4, 
    early_stopping=True)
print(outputs)

# %%
#Final Summarized output
print(t5_tokenizer.decode(outputs[0]))
